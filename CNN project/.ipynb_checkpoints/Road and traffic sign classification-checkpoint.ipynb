# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
import cv2
import imghdr

# %%
data_dir = 'data' 

image_exts = ['jpeg','jpg', 'bmp', 'png']

for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
# Out:
# Image not in ext list data\roads\192px.svg
# Image not in ext list data\roads\best-roads-in-the-world-2022-singapore.jpg
# Image not in ext list data\roads\Best-roads-in-the-world-Lamar-Valley-in-Yellowstone-National-Park.jpg.webp
# Image not in ext list data\roads\dtnext2F2023-012F35e058ab-647b-4a9a-b34b-cfec499d51572FUntitled.jpg
# Image not in ext list data\roads\High-angle-view-of-a-woman-crossing-a-road.jpg
# Image not in ext list data\roads\highland-road-sep302021.jpg
# Image not in ext list data\roads\Highway-1277246_640.jpg
# Image not in ext list data\roads\p0c99n41.jpg
# Image not in ext list data\roads\Roads.webp
# Image not in ext list data\roads\vector.svg
# Image not in ext list data\roads\vector10.svg
# Image not in ext list data\roads\vector11.svg
# Image not in ext list data\roads\vector12.svg
# Image not in ext list data\roads\vector13.svg
# Image not in ext list data\roads\vector14.svg
# Image not in ext list data\roads\vector15.svg
# Image not in ext list data\roads\vector2.svg
# Image not in ext list data\roads\vector3.svg
# Image not in ext list data\roads\vector4.svg
# Image not in ext list data\roads\vector5.svg
# Image not in ext list data\roads\vector6.svg
# Image not in ext list data\roads\vector7.svg
# Image not in ext list data\roads\vector8.svg
# Image not in ext list data\roads\vector9.svg
# Image not in ext list data\roads\which-highway-and-why-an-overview-of-roads-streets-and-their-purpose.jpg
# Image not in ext list data\signs\11333767-road-signs-in-the-forest-murmansk-russia.jpg
# Image not in ext list data\signs\1200px-VyhrazenC3BD_jC3ADzdnC3AD_pruh_pro_cyklisty.jpg
# Image not in ext list data\signs\192px.svg
# Image not in ext list data\signs\2048px-Indonesia_Traffic-signs_Regulatory-sign-03.jpg
# Image not in ext list data\signs\46619707-yield-and-roundabout-traffic-signs.jpg
# Image not in ext list data\signs\50922619-traffic-signs-symbols-on-the-road.jpg
# Image not in ext list data\signs\68585431.jpg
# Image not in ext list data\signs\article1.jpeg
# Image not in ext list data\signs\depositphotos_152488120-stock-illustration-road-signs-collection-isolated-on.jpg
# Image not in ext list data\signs\indian-road-sign-indicating-pedestrian-260nw-1907963794.jpg
# Image not in ext list data\signs\NINTCHDBPICT0004194649371.jpg
# Image not in ext list data\signs\set-road-signs-isolated-on-260nw-548151328.jpg
# Image not in ext list data\signs\traffic-light-against-blue-sky-260nw-621883967.jpg
# Image not in ext list data\signs\vector.svg
# Image not in ext list data\signs\vector10.svg
# Image not in ext list data\signs\vector11.svg
# Image not in ext list data\signs\vector12.svg
# Image not in ext list data\signs\vector13.svg
# Image not in ext list data\signs\vector14.svg
# Image not in ext list data\signs\vector15.svg
# Image not in ext list data\signs\vector2.svg
# Image not in ext list data\signs\vector3.svg
# Image not in ext list data\signs\vector4.svg
# Image not in ext list data\signs\vector5.svg
# Image not in ext list data\signs\vector6.svg
# Image not in ext list data\signs\vector7.svg
# Image not in ext list data\signs\vector8.svg
# Image not in ext list data\signs\vector9.svg

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')

data_iterator = data.as_numpy_iterator()

batch = data_iterator.next()

fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
# Out:
# Found 235 files belonging to 2 classes.

# %%
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.26794302, 0.70925736, 0.9846786 ],
#           [0.29483762, 0.71919423, 0.9948912 ],
#           [0.32187656, 0.7235907 , 0.99767   ],
#           ...,
#           [0.3548407 , 0.7666054 , 0.98695165],
#           [0.3650582 , 0.77933455, 0.9863358 ],
#           [0.37499508, 0.79068136, 0.9847837 ]],
#
#          [[0.27947423, 0.71377146, 0.9870876 ],
#           [0.29946792, 0.722526  , 0.99584866],
#           [0.31434122, 0.7291237 , 0.9953831 ],
#           ...,
#           [0.34475037, 0.76043665, 0.99217683],
#           [0.3492494 , 0.7667126 , 0.9895338 ],
#           [0.3590922 , 0.7782016 , 0.99525243]],
#
#          [[0.29602638, 0.7199969 , 0.9912715 ],
#           [0.3041943 , 0.7316453 , 0.9953921 ],
#           [0.31043965, 0.73448247, 0.9935431 ],
#           ...,
#           [0.34926483, 0.7548408 , 0.98952216],
#           [0.35405478, 0.7601316 , 0.99331045],
#           [0.35821843, 0.7654488 , 0.99516696]],
#
#          ...,
#
#          [[0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           ...,
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843]],
#
#          [[0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           ...,
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843]],
#
#          [[0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           ...,
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843],
#           [0.99607843, 0.99607843, 0.99607843]]],
#
#
#         [[[0.31511948, 0.3717065 , 0.47282475],
#           [0.30111825, 0.36386335, 0.46582416],
#           [0.28543198, 0.34817708, 0.45013785],
#           ...,
#           [0.259375  , 0.31819853, 0.4476103 ],
#           [0.23529412, 0.29496017, 0.44537377],
#           [0.21176471, 0.28935355, 0.43697917]],
#
#          [[0.29159006, 0.35433516, 0.4523744 ],
#           [0.28374693, 0.34649202, 0.44845283],
#           [0.27198222, 0.3386489 , 0.4406097 ],
#           ...,
#           [0.25603554, 0.31485906, 0.44427082],
#           [0.25071996, 0.31346506, 0.45464155],
#           [0.22074142, 0.29272366, 0.4495864 ]],
#
#          [[0.29382658, 0.3565717 , 0.4546109 ],
#           [0.28206187, 0.344807  , 0.44676778],
#           [0.26695773, 0.3336244 , 0.43558517],
#           ...,
#           [0.29469976, 0.35352328, 0.46724877],
#           [0.26812193, 0.3311581 , 0.45969668],
#           [0.24371937, 0.3143076 , 0.47058824]],
#
#          ...,
#
#          [[0.2864277 , 0.2945619 , 0.35338542],
#           [0.36047795, 0.35292587, 0.40782782],
#           [0.19376531, 0.2007353 , 0.25984988],
#           ...,
#           [0.13754596, 0.16107537, 0.22382046],
#           [0.06086091, 0.09615503, 0.15497856],
#           [0.2018842 , 0.2136489 , 0.28031558]],
#
#          [[0.36017156, 0.34448528, 0.4033088 ],
#           [0.4088082 , 0.39590994, 0.45333946],
#           [0.37872243, 0.41009498, 0.46107537],
#           ...,
#           [0.07729779, 0.1008272 , 0.15572916],
#           [0.0905484 , 0.11015625, 0.18466605],
#           [0.08828125, 0.10004596, 0.17455576]],
#
#          [[0.46498162, 0.47282475, 0.52380514],
#           [0.3868413 , 0.40084252, 0.44874388],
#           [0.43999693, 0.4604473 , 0.5324295 ],
#           ...,
#           [0.09408701, 0.10893076, 0.15851715],
#           [0.15880822, 0.17057292, 0.23892464],
#           [0.08682598, 0.09859069, 0.1669424 ]]],
#
#
#         [[[0.23137255, 0.28235295, 0.21568628],
#           [0.25226715, 0.30324754, 0.23658088],
#           [0.34724265, 0.39822304, 0.33155638],
#           ...,
#           [0.6401348 , 0.7185662 , 0.7538603 ],
#           [0.65545344, 0.7338848 , 0.7691789 ],
#           [0.65882355, 0.7372549 , 0.77254903]],
#
#          [[0.23373161, 0.284375  , 0.21871936],
#           [0.25291747, 0.30356085, 0.23790522],
#           [0.34012595, 0.39076933, 0.32511368],
#           ...,
#           [0.6363329 , 0.7147801 , 0.7490474 ],
#           [0.6500718 , 0.72878224, 0.76278627],
#           [0.65309435, 0.7318627 , 0.7658088 ]],
#
#          [[0.24445465, 0.29356617, 0.23250613],
#           [0.2558735 , 0.30498502, 0.24392496],
#           [0.30777732, 0.35688883, 0.2958288 ],
#           ...,
#           [0.6190516 , 0.69757056, 0.72717047],
#           [0.6256099 , 0.7055889 , 0.73372877],
#           [0.6270527 , 0.70735294, 0.73517156]],
#
#          ...,
#
#          [[0.48072916, 0.34739584, 0.31210172],
#           [0.4817876 , 0.34421793, 0.31044826],
#           [0.48659858, 0.32977295, 0.30293256],
#           ...,
#           [0.627451  , 0.6313726 , 0.6117647 ],
#           [0.62285537, 0.62677693, 0.6071691 ],
#           [0.62184435, 0.6257659 , 0.6061581 ]],
#
#          [[0.42098653, 0.28765318, 0.25235906],
#           [0.4228348 , 0.28487024, 0.2512322 ],
#           [0.43123612, 0.27222037, 0.24611002],
#           ...,
#           [0.6320466 , 0.63596815, 0.6163603 ],
#           [0.627451  , 0.6313726 , 0.6117647 ],
#           [0.6264399 , 0.6303615 , 0.61075366]],
#
#          [[0.40784314, 0.27450982, 0.23921569],
#           [0.4098652 , 0.27181372, 0.23820466],
#           [0.4190564 , 0.25955883, 0.23360907],
#           ...,
#           [0.6330576 , 0.63697916, 0.6173713 ],
#           [0.628462  , 0.6323836 , 0.61277574],
#           [0.627451  , 0.6313726 , 0.6117647 ]]],
#
#
#         ...,
#
#
#         [[[0.11372549, 0.40392157, 0.69803923],
#           [0.11372549, 0.40392157, 0.69803923],
#           [0.11372549, 0.40392157, 0.69803923],
#           ...,
#           [0.13333334, 0.4       , 0.6862745 ],
#           [0.13333334, 0.4       , 0.6862745 ],
#           [0.13333334, 0.4       , 0.6862745 ]],
#
#          [[0.11372549, 0.40392157, 0.69803923],
#           [0.11375445, 0.40395054, 0.6980682 ],
#           [0.1138861 , 0.40408218, 0.6981998 ],
#           ...,
#           [0.13367034, 0.400337  , 0.68661153],
#           [0.13367034, 0.400337  , 0.68661153],
#           [0.13367034, 0.400337  , 0.68661153]],
#
#          [[0.11372549, 0.40392157, 0.69803923],
#           [0.1138861 , 0.40408218, 0.6981998 ],
#           [0.11461613, 0.40481222, 0.69892985],
#           ...,
#           [0.1352022 , 0.40186888, 0.6881434 ],
#           [0.1352022 , 0.40186888, 0.6881434 ],
#           [0.1352022 , 0.40186888, 0.6881434 ]],
#
#          ...,
#
#          [[0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           ...,
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354]],
#
#          [[0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           ...,
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354]],
#
#          [[0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           [0.46666667, 0.6745098 , 0.8392157 ],
#           ...,
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354],
#           [0.47058824, 0.7019608 , 0.85882354]]],
#
#
#         [[[0.44099265, 0.57405025, 0.10215992],
#           [0.27037376, 0.39296874, 0.00165441],
#           [0.2511489 , 0.34643075, 0.04601716],
#           ...,
#           [0.22581188, 0.34854472, 0.10286459],
#           [0.2546875 , 0.39420956, 0.1506587 ],
#           [0.24747242, 0.4037837 , 0.15686275]],
#
#          [[0.46191958, 0.59497714, 0.12487578],
#           [0.3676224 , 0.4902174 , 0.08876283],
#           [0.33162412, 0.42690596, 0.12649237],
#           ...,
#           [0.22302222, 0.3420178 , 0.1027406 ],
#           [0.183706  , 0.32274982, 0.08194436],
#           [0.16812193, 0.3244332 , 0.07977941]],
#
#          [[0.4560937 , 0.5902337 , 0.12380707],
#           [0.44545013, 0.5668809 , 0.16151936],
#           [0.3916681 , 0.48578575, 0.1888648 ],
#           ...,
#           [0.19825248, 0.31335664, 0.08340873],
#           [0.14311428, 0.27856207, 0.04649969],
#           [0.12535232, 0.27929425, 0.04215686]],
#
#          ...,
#
#          [[0.67180103, 0.6521932 , 0.48803878],
#           [0.66819805, 0.6481766 , 0.50412023],
#           [0.46472263, 0.4405039 , 0.34543648],
#           ...,
#           [0.43666297, 0.43920588, 0.4555815 ],
#           [0.43645832, 0.43687195, 0.46659008],
#           [0.42889094, 0.44024202, 0.4678309 ]],
#
#          [[0.67319   , 0.65358216, 0.48942775],
#           [0.61233604, 0.5923146 , 0.44825822],
#           [0.43695953, 0.4127408 , 0.3176734 ],
#           ...,
#           [0.43393052, 0.4364734 , 0.45284903],
#           [0.4336397 , 0.4340533 , 0.46377143],
#           [0.4260723 , 0.4374234 , 0.46501225]],
#
#          [[0.65620404, 0.6365962 , 0.4724418 ],
#           [0.567356  , 0.54733455, 0.40327817],
#           [0.4214614 , 0.39724264, 0.30217525],
#           ...,
#           [0.43206188, 0.4346048 , 0.4509804 ],
#           [0.43137255, 0.43178615, 0.46150428],
#           [0.42380515, 0.43515626, 0.4627451 ]]],
#
#
#         [[[0.85882354, 0.9372549 , 0.98039216],
#           [0.85882354, 0.9372549 , 0.98039216],
#           [0.86050856, 0.9389399 , 0.9820772 ],
#           ...,
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ]],
#
#          [[0.85882354, 0.9372549 , 0.98039216],
#           [0.85882354, 0.9372549 , 0.98039216],
#           [0.86050856, 0.9389399 , 0.9820772 ],
#           ...,
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ]],
#
#          [[0.85882354, 0.9372549 , 0.98039216],
#           [0.85882354, 0.9372549 , 0.98039216],
#           [0.86050856, 0.9389399 , 0.9820772 ],
#           ...,
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ],
#           [0.8392157 , 0.9098039 , 0.9882353 ]],
#
#          ...,
#
#          [[0.75059885, 0.75059885, 0.758442  ],
#           [0.7452292 , 0.7452292 , 0.7530723 ],
#           [0.7578575 , 0.7578575 , 0.76570064],
#           ...,
#           [0.3877456 , 0.42472476, 0.10249646],
#           [0.33250996, 0.37362516, 0.07144991],
#           [0.30360657, 0.34366336, 0.05477079]],
#
#          [[0.75106275, 0.75106275, 0.7589059 ],
#           [0.75125515, 0.75125515, 0.7590983 ],
#           [0.7509009 , 0.7509009 , 0.75874406],
#           ...,
#           [0.3624684 , 0.39944756, 0.09001225],
#           [0.33823147, 0.37934667, 0.07827435],
#           [0.31161153, 0.35116422, 0.06387868]],
#
#          [[0.7536152 , 0.7536152 , 0.76145834],
#           [0.7597733 , 0.7597733 , 0.76761645],
#           [0.7484375 , 0.7484375 , 0.75628066],
#           ...,
#           [0.34154412, 0.3785233 , 0.08051471],
#           [0.34001225, 0.38112745, 0.08005515],
#           [0.31731004, 0.35686275, 0.0695772 ]]]], dtype=float32),
#  array([1, 0, 1, 0, 1, 1, 1, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 1, 0, 1,
#         1, 0, 1, 0, 0, 0, 0, 1, 0, 1]))

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

train_size
# Out:
# 5

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 254, 254, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 60, 60, 16)        4624
#
#  max_pooling2d_11 (MaxPoolin  (None, 30, 30, 16)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 14400)             0
#
#  dense_8 (Dense)             (None, 256)               3686656
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 5/5 [==============================] - 9s 1s/step - loss: 0.9054 - accuracy: 0.5437 - val_loss: 0.6808 - val_accuracy: 0.5312
# Epoch 2/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.7085 - accuracy: 0.4500 - val_loss: 0.6817 - val_accuracy: 0.8125
# Epoch 3/20
# 5/5 [==============================] - 9s 1s/step - loss: 0.6778 - accuracy: 0.7188 - val_loss: 0.6802 - val_accuracy: 0.5312
# Epoch 4/20
# 5/5 [==============================] - 9s 1s/step - loss: 0.6554 - accuracy: 0.6562 - val_loss: 0.6268 - val_accuracy: 0.6875
# Epoch 5/20
# 5/5 [==============================] - 9s 2s/step - loss: 0.6069 - accuracy: 0.7563 - val_loss: 0.5408 - val_accuracy: 0.9062
# Epoch 6/20
# 5/5 [==============================] - 9s 1s/step - loss: 0.5610 - accuracy: 0.7125 - val_loss: 0.4220 - val_accuracy: 0.9375
# Epoch 7/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.4114 - accuracy: 0.8625 - val_loss: 0.3302 - val_accuracy: 0.9688
# Epoch 8/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.3517 - accuracy: 0.8750 - val_loss: 0.3673 - val_accuracy: 0.8125
# Epoch 9/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.2176 - accuracy: 0.9500 - val_loss: 0.2142 - val_accuracy: 0.9062
# Epoch 10/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.1981 - accuracy: 0.9312 - val_loss: 0.3006 - val_accuracy: 0.8750
# Epoch 11/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.2082 - accuracy: 0.9187 - val_loss: 0.1556 - val_accuracy: 0.9375
# Epoch 12/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.1656 - accuracy: 0.9625 - val_loss: 0.0942 - val_accuracy: 0.9688
# Epoch 13/20
# 5/5 [==============================] - 7s 1s/step - loss: 0.1292 - accuracy: 0.9750 - val_loss: 0.1091 - val_accuracy: 0.9688
# Epoch 14/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.1226 - accuracy: 0.9563 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 15/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.0865 - accuracy: 0.9688 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 16/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.0701 - accuracy: 0.9750 - val_loss: 0.1276 - val_accuracy: 0.9688
# Epoch 17/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.0841 - accuracy: 0.9875 - val_loss: 0.0909 - val_accuracy: 0.9688
# Epoch 18/20
# 5/5 [==============================] - 8s 1s/step - loss: 0.0411 - accuracy: 0.9937 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 19/20
# 5/5 [==============================] - 9s 2s/step - loss: 0.0386 - accuracy: 0.9812 - val_loss: 0.1428 - val_accuracy: 0.9375
# Epoch 20/20
# 5/5 [==============================] - 10s 2s/step - loss: 0.0348 - accuracy: 0.9812 - val_loss: 0.0206 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
    
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32)

# %%
import cv2

# %%
img = cv2.imread('71L0EbialtL.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[1.]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Traffic sign')
else:
    print(f'Predicted class is Road')
# Out:
# Predicted class is Traffic sign
